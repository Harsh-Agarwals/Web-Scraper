# %% [markdown]
# # WEB SCRAPING OF ONLINE BOOK STORE¶
# A online book website consists of about 50 pages with around 20 books in each page. Each book has specification like book name, rating in stars, cost, etc. Using this web scraper code, we will get list and number of all books that have particular rating in stars.
#
# Using requests module to get and load the website and then using BeautifulSoup web scraper python module to scrap the website and get the required list of information.

# %% [markdown]
# # STEP - 1: Importing the important libraries
# importing requests and BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### STEP : Looping through all the pages in the website and then then looping through all the individual books to find the rating in star. Then collecting the names of those books which are of our interest.

# %%
five_rating_books = 0
five_stars_books = []

total_pages = 50

for page in range(1, total_pages + 1):
    page_url = "https://books.toscrape.com/catalogue/page-" + str(page) + ".html"
    r = requests.get(page_url)
    htmlContent = r.content
    
    soup = BeautifulSoup(htmlContent, 'lxml')
    
    five_stars = soup.find_all(class_="star-rating Five")
    for books in five_stars:
        book_title = books.parent.h3.a['title']
        five_stars_books.append(book_title)
        five_rating_books += 1
        
print("Number of books with 5 star rating - ", five_rating_books)
print(five_stars_books)
# Out:
# Number of books with 5 star rating -  196
# ...

# %%
five_stars_books
# Out:
# ['Sapiens: A Brief History of Humankind',
#  'Set Me Free',
#  "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#  'Rip it Up and Start Again',
#  'Chase Me (Paris Nights #2)',
#  'Black Dust',
#  'Worlds Elsewhere: Journeys Around Shakespeare’s Globe',
#  'The Four Agreements: A Practical Guide to Personal Freedom',
#  'The Elephant Tree',
#  "Sophie's World",
#  'Private Paris (Private #10)',
#  '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.',
#  'We Love You, Charlie Freeman',
#  'Thirst',
#  'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer',
#  "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution",
#  'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#  'Princess Between Worlds (Wide-Awake Princess #5)',
#  'Join',
#  'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine',
#  'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle',
# ...
